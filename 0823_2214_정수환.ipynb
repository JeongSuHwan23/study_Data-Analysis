# %% [markdown]
# <a href="https://colab.research.google.com/github/JeongSuHwan23/study_Data-Analysis/blob/master/0823_2214_%EC%A0%95%EC%88%98%ED%99%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = float(input())
x2 = float(input())
y1 = float(input())
y2 = float(input())

x = float(input())

y = float((y2 - y1) / (x2 - x1) * (x - x1) + y1)

print(round(y, 3))
# Out:
# 0
# 100
# 25
# 24.4
# 1000
# 19.0
# 18.999999999999986

# %%
from sklearn.linear_model import LinearRegression
import pandas as df
import matplotlib.pyplot as plt
import numpy as np
data = df.DataFrame( { "altitude":[0,100,200,300, 400], "temperature":[25, 24.4, 23.8, 23.2, 22.6] } )

X = data['altitude']
Y = data['temperature']
lineFit = LinearRegression()
lineFit.fit(X.values.reshape(-1,1), Y)
print('기울기:', lineFit.coef_)
print('절편:', lineFit.intercept_)
print( lineFit.predict(np.array([1000]).reshape(-1,1)) )

plt.plot(X, Y, '*')
plt.plot(X,lineFit.predict(X.values.reshape(-1,1)))
plt.show()
# Out:
# 기울기: [-0.006]
# 절편: 25.0
# [19.]
